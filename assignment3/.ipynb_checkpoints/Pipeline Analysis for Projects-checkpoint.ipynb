# %% [markdown]
# # Pipeline Analysis for Projects

# %%
import re
import time

import pandas as pd
import numpy as np
import pylab as plt
# %matplotlib inline
from sklearn.tree import DecisionTreeClassifier
from sklearn import preprocessing

# %% [markdown]
# ## Read CSV

# %%
#covert a string that is camelcase into snake_case
def camel_to_snake(column_name):
    s1 = re.sub('(.)([A-Z][a-z]+)', r'\1_\2', column_name)
    return re.sub('([a-z0-9])([A-Z])', r'\1_\2', s1).lower()

df_project = pd.read_csv('projects.csv', index_col='projectid')
df_outcomes = pd.read_csv('outcomes.csv', index_col='projectid')
df_project['fully_funded'] = df_outcomes['fully_funded']

# %%
df_project = df_project.dropna()
df_project = df_project[df_project['date_posted'] >= '2011-01-01']
df = df_project[df_project['date_posted'] <= '2013-12-31']
df.columns = [camel_to_snake(col) for col in df.columns]
df.head()
# Out:
#                                                     teacher_acctid  \
# projectid
# 62526d85d2a1818432d03d600969e99c  ebc7c90b6c92a069432e0714b8d93dfd
# 1a3aaeffc56dd2a421e37d8298024c0a  f4c9ed095b85458dcf858e25f203af00
# a4b234feb2b72921ed59850d5c873d62  620982375045fa11d872702f26ab98bb
# 0ff5dec32bf793243a8b0b2c023a81f0  ec5b110df87bd511b508961676d08b6c
# 72d58b8e22adbe6e6aab65d8b2ab4973  0793851e2f40ecc28e40513622aea670
#
#                                                           schoolid  \
# projectid
# 62526d85d2a1818432d03d600969e99c  5aca9711ff0e4b37db48701f46f73036
# 1a3aaeffc56dd2a421e37d8298024c0a  9310d3eb447a4e46bc5fc31ed007ceac
# a4b234feb2b72921ed59850d5c873d62  da1985df161ba5c3842fc99579b6e4b1
# 0ff5dec32bf793243a8b0b2c023a81f0  72e2b0cb2eecfdc37e67e0eaf10da07b
# 72d58b8e22adbe6e6aab65d8b2ab4973  a180e99ef60be5a9c5f96e21f9868f13
#
#                                   school_ncesid  school_latitude  \
# projectid
# 62526d85d2a1818432d03d600969e99c   1.713710e+11        41.972419
# 1a3aaeffc56dd2a421e37d8298024c0a   3.302610e+11        42.888244
# a4b234feb2b72921ed59850d5c873d62   2.102990e+11        38.249919
# 0ff5dec32bf793243a8b0b2c023a81f0   1.201980e+11        30.507978
# 72d58b8e22adbe6e6aab65d8b2ab4973   5.606090e+11        44.097156
#
#                                   school_longitude school_city school_state  \
# projectid
# 62526d85d2a1818432d03d600969e99c        -88.174597    Bartlett           IL
# 1a3aaeffc56dd2a421e37d8298024c0a        -71.320224       Derry           NH
# a4b234feb2b72921ed59850d5c873d62        -85.722310  Louisville           KY
# 0ff5dec32bf793243a8b0b2c023a81f0        -86.132003    Freeport           FL
# 72d58b8e22adbe6e6aab65d8b2ab4973       -104.622147       Upton           WY
#
#                                   school_zip school_metro  \
# projectid
# 62526d85d2a1818432d03d600969e99c     60103.0     suburban
# 1a3aaeffc56dd2a421e37d8298024c0a      3038.0     suburban
# a4b234feb2b72921ed59850d5c873d62     40206.0        urban
# 0ff5dec32bf793243a8b0b2c023a81f0     32439.0        rural
# 72d58b8e22adbe6e6aab65d8b2ab4973     82730.0        rural
#
#                                                 school_district     ...       \
# projectid                                                           ...
# 62526d85d2a1818432d03d600969e99c     Elgin School District U-46     ...
# 1a3aaeffc56dd2a421e37d8298024c0a  School Administrative Unit 10     ...
# a4b234feb2b72921ed59850d5c873d62   Jefferson Co School District     ...
# 0ff5dec32bf793243a8b0b2c023a81f0      Walton Co School District     ...
# 72d58b8e22adbe6e6aab65d8b2ab4973    Weston Co School District 7     ...
#
#                                      poverty_level    grade_level  \
# projectid
# 62526d85d2a1818432d03d600969e99c  moderate poverty     Grades 3-5
# 1a3aaeffc56dd2a421e37d8298024c0a  moderate poverty     Grades 6-8
# a4b234feb2b72921ed59850d5c873d62   highest poverty  Grades PreK-2
# 0ff5dec32bf793243a8b0b2c023a81f0   highest poverty  Grades PreK-2
# 72d58b8e22adbe6e6aab65d8b2ab4973  moderate poverty  Grades PreK-2
#
#                                  fulfillment_labor_materials  \
# projectid
# 62526d85d2a1818432d03d600969e99c                        30.0
# 1a3aaeffc56dd2a421e37d8298024c0a                        30.0
# a4b234feb2b72921ed59850d5c873d62                        30.0
# 0ff5dec32bf793243a8b0b2c023a81f0                        30.0
# 72d58b8e22adbe6e6aab65d8b2ab4973                        30.0
#
#                                  total_price_excluding_optional_support  \
# projectid
# 62526d85d2a1818432d03d600969e99c                                 444.36
# 1a3aaeffc56dd2a421e37d8298024c0a                                 285.09
# a4b234feb2b72921ed59850d5c873d62                                 935.16
# 0ff5dec32bf793243a8b0b2c023a81f0                                 809.32
# 72d58b8e22adbe6e6aab65d8b2ab4973                                 297.85
#
#                                  total_price_including_optional_support  \
# projectid
# 62526d85d2a1818432d03d600969e99c                                 522.78
# 1a3aaeffc56dd2a421e37d8298024c0a                                 335.40
# a4b234feb2b72921ed59850d5c873d62                                1100.19
# 0ff5dec32bf793243a8b0b2c023a81f0                                 952.14
# 72d58b8e22adbe6e6aab65d8b2ab4973                                 350.41
#
#                                  students_reached  \
# projectid
# 62526d85d2a1818432d03d600969e99c              7.0
# 1a3aaeffc56dd2a421e37d8298024c0a            230.0
# a4b234feb2b72921ed59850d5c873d62             25.0
# 0ff5dec32bf793243a8b0b2c023a81f0             17.0
# 72d58b8e22adbe6e6aab65d8b2ab4973             21.0
#
#                                  eligible_double_your_impact_match  \
# projectid
# 62526d85d2a1818432d03d600969e99c                                 f
# 1a3aaeffc56dd2a421e37d8298024c0a                                 f
# a4b234feb2b72921ed59850d5c873d62                                 t
# 0ff5dec32bf793243a8b0b2c023a81f0                                 f
# 72d58b8e22adbe6e6aab65d8b2ab4973                                 f
#
#                                  eligible_almost_home_match date_posted  \
# projectid
# 62526d85d2a1818432d03d600969e99c                          f  2013-12-31
# 1a3aaeffc56dd2a421e37d8298024c0a                          f  2013-12-31
# a4b234feb2b72921ed59850d5c873d62                          f  2013-12-31
# 0ff5dec32bf793243a8b0b2c023a81f0                          f  2013-12-31
# 72d58b8e22adbe6e6aab65d8b2ab4973                          f  2013-12-31
#
#                                  fully_funded
# projectid
# 62526d85d2a1818432d03d600969e99c            t
# 1a3aaeffc56dd2a421e37d8298024c0a            f
# a4b234feb2b72921ed59850d5c873d62            f
# 0ff5dec32bf793243a8b0b2c023a81f0            t
# 72d58b8e22adbe6e6aab65d8b2ab4973            t
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Explore Data

# %%
df.count()
# Out:
# teacher_acctid                            197947
# schoolid                                  197947
# school_ncesid                             197947
# school_latitude                           197947
# school_longitude                          197947
# school_city                               197947
# school_state                              197947
# school_zip                                197947
# school_metro                              197947
# school_district                           197947
# school_county                             197947
# school_charter                            197947
# school_magnet                             197947
# school_year_round                         197947
# school_nlns                               197947
# school_kipp                               197947
# school_charter_ready_promise              197947
# teacher_prefix                            197947
# teacher_teach_for_america                 197947
# teacher_ny_teaching_fellow                197947
# primary_focus_subject                     197947
# primary_focus_area                        197947
# secondary_focus_subject                   197947
# secondary_focus_area                      197947
# resource_type                             197947
# poverty_level                             197947
# grade_level                               197947
# fulfillment_labor_materials               197947
# total_price_excluding_optional_support    197947
# total_price_including_optional_support    197947
# students_reached                          197947
# eligible_double_your_impact_match         197947
# eligible_almost_home_match                197947
# date_posted                               197947
# fully_funded                              197947
# dtype: int64

# %%
# figure out which variables contain null values. 
# First, melt our data into long format.
# print a table telling the no of null and non-null instances.
df_lng = pd.melt(df)
null_variables = df_lng.value.isnull()
pd.crosstab(df_lng.variable, null_variables)
# Out:
# value                                    False
# variable
# date_posted                             197947
# eligible_almost_home_match              197947
# eligible_double_your_impact_match       197947
# fulfillment_labor_materials             197947
# fully_funded                            197947
# grade_level                             197947
# poverty_level                           197947
# primary_focus_area                      197947
# primary_focus_subject                   197947
# resource_type                           197947
# school_charter                          197947
# school_charter_ready_promise            197947
# school_city                             197947
# school_county                           197947
# school_district                         197947
# school_kipp                             197947
# school_latitude                         197947
# school_longitude                        197947
# school_magnet                           197947
# school_metro                            197947
# school_ncesid                           197947
# school_nlns                             197947
# school_state                            197947
# school_year_round                       197947
# school_zip                              197947
# schoolid                                197947
# secondary_focus_area                    197947
# secondary_focus_subject                 197947
# students_reached                        197947
# teacher_acctid                          197947
# teacher_ny_teaching_fellow              197947
# teacher_prefix                          197947
# teacher_teach_for_america               197947
# total_price_excluding_optional_support  197947
# total_price_including_optional_support  197947

# %% [markdown]
# ## Pre Process Data

# %%
def check_missing(df):
    return [col for col in df.columns if any(df[col].isnull()) == True]

def fill_missing(df, col_name, method):
    if method == 'mean':
        df[col_name] = df[col_name].fillna(df[col_name].mean())
    elif method == 'median':
        df[col_name] = df[col_name].fillna(df[col_name].median())
    elif method == 'zero':
        df[col_name] = df[col_name].fillna(0)
        
missing_cols = check_missing(df)
missing_cols
# Out:
# []

# %%
for col in missing_cols:
    fill_missing(df, col, 'mean')
check_missing(df)
# Out:
# []

# %% [markdown]
# As we can see, there is no missing values.

# %%
label_name = 'fully_funded'
exclude_names = ['schoolid', 'teacher_acctid', 'school_city', 'school_zip',
                 'school_district', 'date_posted', 'school_county']
feature_names = [col for col in df.columns if col != label_name and col not in exclude_names]
df = df.sort_values(by='date_posted')
df = df[feature_names + [label_name]]

# replace f with 0, t with 1
df = df.replace('f', 0).replace('t', 1)

# %%
# encode data by unique number idx
encoded_features = ['school_state', 'school_metro', 'resource_type', 'poverty_level',
                    'grade_level', 'primary_focus_area', 'primary_focus_subject',
                    'secondary_focus_subject', 'secondary_focus_area', 'teacher_prefix']
for col in encoded_features:
    df[col] = df[col].astype('category').cat.codes
df.head()
# Out:
#                                   school_ncesid  school_latitude  \
# projectid
# 5642f0ce487ab43a26b51b9af9820a36   3.200060e+11        36.178444
# ee279dfe26913547e95a55175a344e8b   3.600139e+11        40.806160
# 84adb497b27d78f5dd81462e977f9632   3.600098e+11        40.745975
# 23961f66f372f2d5f1e94dc3719abc2d   1.301740e+11        33.650887
# b58bc950a370da38f4832f3a9e120ee3   1.024300e+10        32.398838
#
#                                   school_longitude  school_state  \
# projectid
# 5642f0ce487ab43a26b51b9af9820a36       -115.113045            33
# ee279dfe26913547e95a55175a344e8b        -73.948020            34
# 84adb497b27d78f5dd81462e977f9632        -73.879639            34
# 23961f66f372f2d5f1e94dc3719abc2d        -84.127312            10
# b58bc950a370da38f4832f3a9e120ee3        -86.278961             1
#
#                                   school_metro  school_charter  school_magnet  \
# projectid
# 5642f0ce487ab43a26b51b9af9820a36             2               0              0
# ee279dfe26913547e95a55175a344e8b             2               1              0
# 84adb497b27d78f5dd81462e977f9632             2               0              0
# 23961f66f372f2d5f1e94dc3719abc2d             1               0              0
# b58bc950a370da38f4832f3a9e120ee3             2               0              0
#
#                                   school_year_round  school_nlns  school_kipp  \
# projectid
# 5642f0ce487ab43a26b51b9af9820a36                  0            0            0
# ee279dfe26913547e95a55175a344e8b                  0            1            0
# 84adb497b27d78f5dd81462e977f9632                  0            0            0
# 23961f66f372f2d5f1e94dc3719abc2d                  0            0            0
# b58bc950a370da38f4832f3a9e120ee3                  0            0            0
#
#                                       ...       resource_type  poverty_level  \
# projectid                             ...
# 5642f0ce487ab43a26b51b9af9820a36      ...                   3              1
# ee279dfe26913547e95a55175a344e8b      ...                   3              0
# 84adb497b27d78f5dd81462e977f9632      ...                   2              1
# 23961f66f372f2d5f1e94dc3719abc2d      ...                   3              1
# b58bc950a370da38f4832f3a9e120ee3      ...                   2              1
#
#                                   grade_level  fulfillment_labor_materials  \
# projectid
# 5642f0ce487ab43a26b51b9af9820a36            3                         35.0
# ee279dfe26913547e95a55175a344e8b            3                         35.0
# 84adb497b27d78f5dd81462e977f9632            0                         35.0
# 23961f66f372f2d5f1e94dc3719abc2d            0                         35.0
# b58bc950a370da38f4832f3a9e120ee3            0                         35.0
#
#                                   total_price_excluding_optional_support  \
# projectid
# 5642f0ce487ab43a26b51b9af9820a36                                  722.71
# ee279dfe26913547e95a55175a344e8b                                 2076.99
# 84adb497b27d78f5dd81462e977f9632                                  826.58
# 23961f66f372f2d5f1e94dc3719abc2d                                  296.30
# b58bc950a370da38f4832f3a9e120ee3                                  911.60
#
#                                   total_price_including_optional_support  \
# projectid
# 5642f0ce487ab43a26b51b9af9820a36                                  850.25
# ee279dfe26913547e95a55175a344e8b                                 2443.52
# 84adb497b27d78f5dd81462e977f9632                                  972.45
# 23961f66f372f2d5f1e94dc3719abc2d                                  348.59
# b58bc950a370da38f4832f3a9e120ee3                                 1072.47
#
#                                   students_reached  \
# projectid
# 5642f0ce487ab43a26b51b9af9820a36              18.0
# ee279dfe26913547e95a55175a344e8b              16.0
# 84adb497b27d78f5dd81462e977f9632              30.0
# 23961f66f372f2d5f1e94dc3719abc2d             500.0
# b58bc950a370da38f4832f3a9e120ee3              42.0
#
#                                   eligible_double_your_impact_match  \
# projectid
# 5642f0ce487ab43a26b51b9af9820a36                                  1
# ee279dfe26913547e95a55175a344e8b                                  0
# 84adb497b27d78f5dd81462e977f9632                                  0
# 23961f66f372f2d5f1e94dc3719abc2d                                  0
# b58bc950a370da38f4832f3a9e120ee3                                  0
#
#                                   eligible_almost_home_match  fully_funded
# projectid
# 5642f0ce487ab43a26b51b9af9820a36                           0             1
# ee279dfe26913547e95a55175a344e8b                           0             0
# 84adb497b27d78f5dd81462e977f9632                           0             0
# 23961f66f372f2d5f1e94dc3719abc2d                           0             1
# b58bc950a370da38f4832f3a9e120ee3                           0             1
#
# [5 rows x 28 columns]

# %% [markdown]
# ##  Generate Features

# %%
def sort_features_through_dt(df_features, df_label):
    features = df_features.columns
    model = DecisionTreeClassifier()
    model.fit(df_features, df_label)
    importances = model.feature_importances_
    sorted_idx = np.argsort(importances)
    padding = np.arange(len(features)) + 0.5
    plt.figure(figsize=(5, 8))
    plt.barh(padding, importances[sorted_idx], align='center')
    plt.yticks(padding, np.asarray(features)[sorted_idx])
    plt.xlabel("Relative Importance")
    plt.title("Features Importance Through DT")
    
    return list(np.asarray(features)[sorted_idx][::-1])


df_features, df_label = df[feature_names], df[label_name]

# sort all the features by importance
sorted_features = sort_features_through_dt(df_features, df_label)

# %%
# Select top 2/3 features
count = int(len(sorted_features) * 0.67)
df_features = df_features[sorted_features[:count]]
df_features.head()
# Out:
#                                   total_price_excluding_optional_support  \
# projectid
# 5642f0ce487ab43a26b51b9af9820a36                                  722.71
# ee279dfe26913547e95a55175a344e8b                                 2076.99
# 84adb497b27d78f5dd81462e977f9632                                  826.58
# 23961f66f372f2d5f1e94dc3719abc2d                                  296.30
# b58bc950a370da38f4832f3a9e120ee3                                  911.60
#
#                                   school_longitude  school_latitude  \
# projectid
# 5642f0ce487ab43a26b51b9af9820a36       -115.113045        36.178444
# ee279dfe26913547e95a55175a344e8b        -73.948020        40.806160
# 84adb497b27d78f5dd81462e977f9632        -73.879639        40.745975
# 23961f66f372f2d5f1e94dc3719abc2d        -84.127312        33.650887
# b58bc950a370da38f4832f3a9e120ee3        -86.278961        32.398838
#
#                                   students_reached  \
# projectid
# 5642f0ce487ab43a26b51b9af9820a36              18.0
# ee279dfe26913547e95a55175a344e8b              16.0
# 84adb497b27d78f5dd81462e977f9632              30.0
# 23961f66f372f2d5f1e94dc3719abc2d             500.0
# b58bc950a370da38f4832f3a9e120ee3              42.0
#
#                                   total_price_including_optional_support  \
# projectid
# 5642f0ce487ab43a26b51b9af9820a36                                  850.25
# ee279dfe26913547e95a55175a344e8b                                 2443.52
# 84adb497b27d78f5dd81462e977f9632                                  972.45
# 23961f66f372f2d5f1e94dc3719abc2d                                  348.59
# b58bc950a370da38f4832f3a9e120ee3                                 1072.47
#
#                                   school_ncesid  secondary_focus_subject  \
# projectid
# 5642f0ce487ab43a26b51b9af9820a36   3.200060e+11                        5
# ee279dfe26913547e95a55175a344e8b   3.600139e+11                       17
# 84adb497b27d78f5dd81462e977f9632   3.600098e+11                        5
# 23961f66f372f2d5f1e94dc3719abc2d   1.301740e+11                       15
# b58bc950a370da38f4832f3a9e120ee3   1.024300e+10                       23
#
#                                   primary_focus_subject  resource_type  \
# projectid
# 5642f0ce487ab43a26b51b9af9820a36                     15              3
# ee279dfe26913547e95a55175a344e8b                     15              3
# 84adb497b27d78f5dd81462e977f9632                      1              2
# 23961f66f372f2d5f1e94dc3719abc2d                     23              3
# b58bc950a370da38f4832f3a9e120ee3                     17              2
#
#                                   secondary_focus_area  grade_level  \
# projectid
# 5642f0ce487ab43a26b51b9af9820a36                     3            3
# ee279dfe26913547e95a55175a344e8b                     4            3
# 84adb497b27d78f5dd81462e977f9632                     3            0
# 23961f66f372f2d5f1e94dc3719abc2d                     3            0
# b58bc950a370da38f4832f3a9e120ee3                     2            0
#
#                                   teacher_prefix  primary_focus_area  \
# projectid
# 5642f0ce487ab43a26b51b9af9820a36               3                   3
# ee279dfe26913547e95a55175a344e8b               3                   3
# 84adb497b27d78f5dd81462e977f9632               2                   0
# 23961f66f372f2d5f1e94dc3719abc2d               3                   2
# b58bc950a370da38f4832f3a9e120ee3               3                   4
#
#                                   poverty_level  fulfillment_labor_materials  \
# projectid
# 5642f0ce487ab43a26b51b9af9820a36              1                         35.0
# ee279dfe26913547e95a55175a344e8b              0                         35.0
# 84adb497b27d78f5dd81462e977f9632              1                         35.0
# 23961f66f372f2d5f1e94dc3719abc2d              1                         35.0
# b58bc950a370da38f4832f3a9e120ee3              1                         35.0
#
#                                   school_metro  \
# projectid
# 5642f0ce487ab43a26b51b9af9820a36             2
# ee279dfe26913547e95a55175a344e8b             2
# 84adb497b27d78f5dd81462e977f9632             2
# 23961f66f372f2d5f1e94dc3719abc2d             1
# b58bc950a370da38f4832f3a9e120ee3             2
#
#                                   eligible_double_your_impact_match  \
# projectid
# 5642f0ce487ab43a26b51b9af9820a36                                  1
# ee279dfe26913547e95a55175a344e8b                                  0
# 84adb497b27d78f5dd81462e977f9632                                  0
# 23961f66f372f2d5f1e94dc3719abc2d                                  0
# b58bc950a370da38f4832f3a9e120ee3                                  0
#
#                                   school_state
# projectid
# 5642f0ce487ab43a26b51b9af9820a36            33
# ee279dfe26913547e95a55175a344e8b            34
# 84adb497b27d78f5dd81462e977f9632            34
# 23961f66f372f2d5f1e94dc3719abc2d            10
# b58bc950a370da38f4832f3a9e120ee3             1

# %%
# normalize
df_features = preprocessing.MinMaxScaler().fit_transform(df_features)
df_features = preprocessing.normalize(df_features, norm='max')

# %% [markdown]
# ## Build Classifier

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import ParameterGrid, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import (RandomForestClassifier,
                              GradientBoostingClassifier,
                              BaggingClassifier)
from sklearn.svm import LinearSVC
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.dummy import DummyClassifier
from sklearn.metrics import (precision_recall_curve, roc_auc_score, roc_curve, auc,
                             precision_score, recall_score, f1_score)

# %%
# split train set and test set
df_features, df_label = df_features[:10000], df_label[:10000]
X_train, X_test, y_train, y_test = train_test_split(df_features, df_label, test_size=0.2)

# %%
classifier_constructors = {
    'LR': LogisticRegression,
    'KNN': KNeighborsClassifier,
    'DT': DecisionTreeClassifier,
    'SVM': LinearSVC,
    'RF': RandomForestClassifier,
    'GB': GradientBoostingClassifier,
    'BG': BaggingClassifier
}

grid = dict()
grid['LR'] = {'penalty': ['l1', 'l2']}
grid['DT'] = {'max_depth': [1, 20, 50]}
grid['KNN'] = {'n_neighbors': [1, 5, 10]}
grid['SVM'] = {'C': [0.1, 0.5, 1]}
grid['RF'] = {'n_estimators': [1, 5, 10]}
grid['GB'] = {'n_estimators': [1, 5, 10]}
grid['BG'] = {'n_estimators': [1, 5, 10]}

# %%
def build_clf(X_train, y_train):
    classifiers = dict()
    for k, clf_constructor in classifier_constructors.items():
        clf = GridSearchCV(clf_constructor(), grid[k], cv=5)
        clf.fit(X_train, y_train)
        classifiers[k] = clf
        print('%s best params: %s, best score: %.4f' % (k, clf.best_params_, clf.best_score_))
    
    return classifiers

    
classifiers = build_clf(X_train, y_train)
# Out:
# LR best params: {'penalty': 'l1'}, best score: 0.6835
# KNN best params: {'n_neighbors': 10}, best score: 0.6434
# DT best params: {'max_depth': 1}, best score: 0.6418
# SVM best params: {'C': 1}, best score: 0.6791
# RF best params: {'n_estimators': 10}, best score: 0.6826
# GB best params: {'n_estimators': 10}, best score: 0.6725
# BG best params: {'n_estimators': 10}, best score: 0.6885

# %% [markdown]
# ## Evaluate Classifier

# %% [markdown]
# ### Calculate precision, recall, f1, and auc

# %%
# evalute metrics
def evaluate_classifier(y_test, y_pre, y_prob, cost_time=0):
    return {
        'precision': float("%.4f" % precision_score(y_test, y_pre)),
        'recall': float("%.4f" % recall_score(y_test, y_pre)),
        'f1': float("%.4f" % f1_score(y_test, y_pre)),
        'auc': float("%.4f" % roc_auc_score(y_test, y_prob)),
        'cost_time': float("%.4f" % cost_time)
    }

def evaluate_classifiers(X_test, y_test, threshold):
    metrics = dict()
    probas = dict()
    for k, clf in classifiers.items():
        start = time.time()
        if hasattr(clf, 'predict_proba'):
            y_prob = clf.predict_proba(X_test)[:, 1]
        else:
            y_prob = clf.decision_function(X_test)
        y_pre = np.asarray([1 if run >= threshold else 0 for run in y_prob])
        cost_time = time.time() - start
        metrics[k] = evaluate_classifier(y_test, y_pre, y_prob, cost_time)
        probas[k] = y_prob
    return metrics, probas
        
metrics, probas = evaluate_classifiers(X_test, y_test, 0.05)
metrics
# Out:
# {'BG': {'auc': 0.72,
#   'cost_time': 0.0055,
#   'f1': 0.788,
#   'precision': 0.6525,
#   'recall': 0.9946},
#  'DT': {'auc': 0.6119,
#   'cost_time': 0.0006,
#   'f1': 0.7868,
#   'precision': 0.6485,
#   'recall': 1.0},
#  'GB': {'auc': 0.7021,
#   'cost_time': 0.001,
#   'f1': 0.7868,
#   'precision': 0.6485,
#   'recall': 1.0},
#  'KNN': {'auc': 0.6657,
#   'cost_time': 0.2744,
#   'f1': 0.7864,
#   'precision': 0.6483,
#   'recall': 0.9992},
#  'LR': {'auc': 0.6985,
#   'cost_time': 0.001,
#   'f1': 0.7868,
#   'precision': 0.6491,
#   'recall': 0.9985},
#  'RF': {'auc': 0.7173,
#   'cost_time': 0.0044,
#   'f1': 0.7881,
#   'precision': 0.6512,
#   'recall': 0.9977},
#  'SVM': {'auc': 0.6958,
#   'cost_time': 0.0006,
#   'f1': 0.7807,
#   'precision': 0.7172,
#   'recall': 0.8566}}

# %% [markdown]
# ### Draw AUC

# %%
def draw_auc(probas, y_test):
    plt.clf()
    auc_list = []
    for k, prob in probas.items():
        fpr, tpr, thresholds = roc_curve(y_test, prob)
        roc_auc = auc(fpr, tpr)
        auc_list.append((k, roc_auc))
        
    auc_list.sort(key=lambda x: x[1], reverse=True)
    
    for k, roc_auc in auc_list:
        fpr, tpr, thresholds = roc_curve(y_test, probas[k])
        plt.plot(fpr, tpr, lw=1, label=('%s AUC %.2f' % (k, roc_auc)))
    
    
    plt.plot([0, 1], [0, 1], '--', color=(0.6, 0.6, 0.6), label='Luck')
    plt.xlim([-0.05, 1.05])
    plt.ylim([-0.05, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('AUC Graph')
    plt.legend(loc="lower right")

draw_auc(probas, y_test)

# %% [markdown]
# ### Draw Precision-Recall Curves

# %%
def plot_precision_recall(y_test, key):
    plt.clf()
    y_prob = probas[key]
    precision_curve, recall_curve, pr_thresholds = precision_recall_curve(y_test, y_prob)
    precision_curve = precision_curve[:-1]
    recall_curve = recall_curve[:-1]
    pct_per_thresh = []
    number_scored = len(y_prob)
    for value in pr_thresholds:
        num_above_thresh = len(y_prob[y_prob >= value])
        pct_above_thresh = num_above_thresh / float(number_scored)
        pct_per_thresh.append(pct_above_thresh)
    pct_per_thresh = np.array(pct_per_thresh)
    plt.clf()
    fig, ax1 = plt.subplots()
    ax1.plot(pct_per_thresh, precision_curve, 'b')
    ax1.set_xlabel('percent of population')
    ax1.set_ylabel('precision', color='b')
    ax2 = ax1.twinx()
    ax2.plot(pct_per_thresh, recall_curve, 'y')
    ax2.set_ylabel('recall', color='y')
    plt.title(key)
    plt.show()
    
for key in probas.keys():
    plot_precision_recall(y_test, key)

# %% [markdown]
# ### Draw Precision, Recall, Auc and F1

# %%
data = dict()
data['key'] =  ['precision', 'recall', 'f1', 'auc', 'cost_time']

for k, metric in metrics.items():
    data[k] = [metric[item] for item in data['key']]

df_result = pd.DataFrame(data)

df_result = df_result.set_index('key')
df_result.head()
# Out:
#                BG      DT      GB     KNN      LR      RF     SVM
# key
# precision  0.6525  0.6485  0.6485  0.6483  0.6491  0.6512  0.7172
# recall     0.9946  1.0000  1.0000  0.9992  0.9985  0.9977  0.8566
# f1         0.7880  0.7868  0.7868  0.7864  0.7868  0.7881  0.7807
# auc        0.7200  0.6119  0.7021  0.6657  0.6985  0.7173  0.6958
# cost_time  0.0055  0.0006  0.0010  0.2744  0.0010  0.0044  0.0006

# %%
df_result.plot.bar();
plt.show()

# %% [markdown]
# ### The Best Classifier

# %%
# find the best one
def find_the_best_model(target='auc'):
    metrics_list = list(metrics.items())
    metrics_list.sort(key=lambda x: x[1][target], reverse=True)
    return metrics_list[0]

best = find_the_best_model('precision')
best
# Out:
# ('SVM',
#  {'auc': 0.6958,
#   'cost_time': 0.0006,
#   'f1': 0.7807,
#   'precision': 0.7172,
#   'recall': 0.8566})

# %%
def get_baseline_metric():
    base_clf = DummyClassifier()
    base_clf.fit(X_train, y_train)
    start = time.time()
    y_pre = base_clf.predict(X_test)
    cost_time = time.time() - start
    y_prob = base_clf.predict_proba(X_test)[:, 1]
    return evaluate_classifier(y_test, y_pre, y_prob, cost_time)

baseline_metric = get_baseline_metric()
('Baseline', baseline_metric)
# Out:
# ('Baseline',
#  {'auc': 0.4843,
#   'cost_time': 0.0002,
#   'f1': 0.6397,
#   'precision': 0.6402,
#   'recall': 0.6392})

# %% [markdown]
# ## Compare to Baseline

# %%
thresholds = [0.01, 0.02, 0.05, 0.1, 0.2, 0.3, 0.5]
threshold_metrics = {}
for threshold in thresholds:
    threshold_metrics[str(threshold)] = evaluate_classifiers(X_test, y_test, threshold)[0]

# %%
data = dict()
data['key'] =  ['best-%s' % item for item in thresholds] + ['baseline']

for k in ['recall', 'f1', 'auc', 'precision', 'cost_time']:
    data[k] = [threshold_metrics[str(threshold)][best[0]][k] for threshold in thresholds]
    data[k].append(baseline_metric[k])

    
df_result = pd.DataFrame(data)
df_result = df_result.set_index('key')
df_result = df_result.sort_values(by='precision')[::-1]
df_result.head(10)
# Out:
#               auc  cost_time      f1  precision  recall
# key
# best-0.5   0.6958     0.0006  0.4523     0.8198  0.3123
# best-0.3   0.6958     0.0006  0.6516     0.7886  0.5551
# best-0.2   0.6958     0.0006  0.7148     0.7580  0.6762
# best-0.1   0.6958     0.0007  0.7667     0.7365  0.7995
# best-0.05  0.6958     0.0006  0.7807     0.7172  0.8566
# best-0.02  0.6958     0.0006  0.7919     0.7139  0.8890
# best-0.01  0.6958     0.0006  0.7932     0.7097  0.8990
# baseline   0.4843     0.0002  0.6397     0.6402  0.6392

# %% [markdown]
# As we see, when threshold equals 0.5, the classifier perform best.
# But baseline classifier cost the least.
